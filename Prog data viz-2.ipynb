# %%
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.plotting import figure, output_file, show
import pandas as pd
import random

# %%
data = pd.read_csv("/Users/ruthvikb/Downloads/covid.csv")

# %%
display(data.head(10))
# Out:
#                   State Month, Day, Year of Date Updated  \
# 0               Alabama                        27-Nov-21
# 1                Alaska                        27-Nov-21
# 2               Arizona                        27-Nov-21
# 3              Arkansas                        27-Nov-21
# 4            California                        27-Nov-21
# 5              Colorado                        27-Nov-21
# 6           Connecticut                        27-Nov-21
# 7              Delaware                        27-Nov-21
# 8  District of Columbia                        27-Nov-21
# 9               Florida                        27-Nov-21
#
#    Number of Deaths (Men)  Number of Deaths (Women)  Pct Deaths F  \
# 0                     NaN                       NaN           NaN
# 1                   510.0                     337.0          39.8
# 2                 13043.0                    9168.0          41.3
# 3                     NaN                       NaN           NaN
# ...

# %%
plt.figure(figsize=(10,20))
plt.barh(data['State'], data['Number of Deaths (Women)'])
plt.xlabel("No of deaths (Women)")
plt.ylabel("State")
plt.title(" Number of deaths(Women) in US states due to covid")
#plt.style.use('ggplot')
plt.show()
