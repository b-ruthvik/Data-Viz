# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets
#import plotly.express as px
#import plotly.figure_factory as FF
#import plotly.plotly as py
#import plotly.graph_objs as go
from matplotlib.pyplot import figure

# %%
ufos = pd.read_csv('/Users/ruthvikb/Downloads/ufo-scrubbed-geocoded-time-standardized-00.csv')

# %%
ufos
# Out:
#         Observed_date                  City State Country     shape  \
# 0      10/10/49 20:30            san marcos    tx      us  cylinder
# 1      10/10/49 21:00          lackland afb    tx     NaN     light
# 2      10/10/55 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/56 21:00                  edna    tx      us    circle
# 4      10/10/60 20:00               kaneohe    hi      us     light
# ...               ...                   ...   ...     ...       ...
# 80327    9/9/13 21:15             nashville    tn      us     light
# 80328    9/9/13 22:00                 boise    id      us    circle
# 80329    9/9/13 22:00                  napa    ca      us     other
# 80330    9/9/13 22:20                vienna    va      us    circle
# 80331    9/9/13 23:00                edmond    ok      us     cigar
#
#        Duration(seconds) Duration(hrs/min)  \
# 0                 2700.0        45 minutes
# 1                 7200.0           1-2 hrs
# ...

# %%
ufos = ufos.fillna({'City':'unkown', 'Country':'unknown', 'State':'unknown', 'Shape':'unknown' })

# %%
ufos
# Out:
#         Observed_date                  City    State  Country     shape  \
# 0      10/10/49 20:30            san marcos       tx       us  cylinder
# 1      10/10/49 21:00          lackland afb       tx  unknown     light
# 2      10/10/55 17:00  chester (uk/england)  unknown       gb    circle
# 3      10/10/56 21:00                  edna       tx       us    circle
# 4      10/10/60 20:00               kaneohe       hi       us     light
# ...               ...                   ...      ...      ...       ...
# 80327    9/9/13 21:15             nashville       tn       us     light
# 80328    9/9/13 22:00                 boise       id       us    circle
# 80329    9/9/13 22:00                  napa       ca       us     other
# 80330    9/9/13 22:20                vienna       va       us    circle
# 80331    9/9/13 23:00                edmond       ok       us     cigar
#
#        Duration(seconds) Duration(hrs/min)  \
# 0                 2700.0        45 minutes
# ...

# %%
ufos["Country"].describe()
# Out:
# count     80332
# unique        6
# top          us
# freq      65114
# Name: Country, dtype: object

# %%
stats = ufos.groupby('Country')["shape"].describe()

# %%
stats
# Out:
#          count unique    top   freq
# Country
# au         527     21  light    119
# ca        2955     22  light    655
# de         103     18  light     20
# gb        1855     21  light    361
# unknown   9399     23  light   1937
# us       63561     28  light  13473

# %%
result = ufos.groupby(['Country']).size() 
sns.barplot(x = result.index, y = result.values)
plt.title('Number of UFO sightings by country', weight = 'bold')
plt.xlabel('Country', weight = 'bold')
#plt.yscale("log")

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.85)
ax.bar(result.index, result.values)
ax.set_xlabel('Country', 
               fontweight ='bold')
ax.set_title('Number of UFO sightings by country', fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Number of UFO sightings by country')

# %%
@ipywidgets.interact(style = plt.style.available)
def make_plot(style): 
    with plt.style.context(style):
        fig, ax = plt.subplots(1,1, figsize=(10,6))
        ax.plot(stats["unique"], marker='.', linewidth=1.0, label="unique")
        #ax.plot(stats["min"], marker='.', linewidth=1.0, label="Min")
        ax.set_label('No of unique shapes by Country')
        ax.set_ylabel ("No of unique shapes")
        ax.set_xlabel ("Country")
        #ax.set_yscale("log")
        #ax.legend()
        plt.ylim(0, 40)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='style', options=('Solarize_Light2', '_classic_test_patch', 'bmh', …
